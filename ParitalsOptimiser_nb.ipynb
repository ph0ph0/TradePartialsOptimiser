# %%
import pandas as pd
from functools import reduce
from itertools import product
import numpy as np
import PartialsCalculator as pc

# list of partials
partials = [20, 50, 100]
at_R = [ 2, 3, 4]
Probability_AtR = [80, 67, 47]
total_shares = 1000


if partials[-1] != 100:
    raise Exception("Final partial must be 100")
if len(partials) != len(at_R):
    raise Exception("Number of partials must be equal to number of AtR")
for idx, probability in enumerate(Probability_AtR):
    if idx == 0:
        continue
    if probability > Probability_AtR[idx - 1]:
        raise Exception("Probabilities must decrease from left to right")

# print(cumsum)
# print(total_profit)

# Now we need to loop through the probability array and do a run for each probability value for each partial percentage between 1 and 99. The number of loops is equal to the max_range^elements. 

# def Caclulate_CumSum_Profit(Partials, AtR):
#     total_shares = 1000
#     remaining_shares = total_shares
#     total_profit = 0
#     profit_array = []
#     for idx, partial in enumerate(Partials):
#         # Percentage of shares to close
#         shares_to_close = remaining_shares * (partial / 100)
#         # print(shares_to_close)
#         remaining_shares = remaining_shares - shares_to_close
#         profit = shares_to_close * AtR[idx]
#         profit_array.append(profit)
#         total_profit += profit
#     return np.cumsum(profit_array)



# ------------------*****************--------------------

# The count of probability will be the same as the count of partial percentage, hence we iterate through this.
def CalculateTotal(partial_array_, at_R_, Probability_AtR_):
    cumsum = pc.Caclulate_CumSum_Profit(partial_array_, at_R_, total_shares)
    total_profit = pc.Total_Profit(Probability_AtR_, cumsum, total_shares)
    return total_profit

t = CalculateTotal(partials, at_R, Probability_AtR)
print(t)








# Produces an array of partial percentages. These are the size of the partials as a percentage of the position after the previous partials.
partials_perc_list = list(product(range(0, 101), repeat=len(at_R)))
# print(partials_perc_list)
results_array = []
# for idx, partial in enumerate(partials_perc_list):
    # print(partial)

# print(len(partials_perc_list))

for partial_tuple in partials_perc_list:
    if (partial_tuple[-1] != 100):
        continue
    # print(partial_tuple)
    total = CalculateTotal(partial_tuple, at_R, Probability_AtR)
    results_array.append((partial_tuple, total))


sorted_results = sorted(results_array, key = lambda x: x[1], reverse = True)
print(sorted_results)

# NOTE: The output is telling us that for Simon's case, he is best off partialling heavily at 3R (assuming that he isn't playing an all day trend). 
# Would he agree that this aligns with his MFE value?

# The problem is that the best result always liquidates the position at 2R! This can't be true.
# Need to work out how much you make if you liquidate all at the first R, vs if you hold through the Rs.
# Out:
# 2076000.0
# [((0, 100, 100), 2210000.0), ((0, 99, 100), 2208700.0), ((0, 98, 100), 2207400.0), ((0, 97, 100), 2206100.0), ((1, 100, 100), 2205900.0), ((0, 96, 100), 2204800.0), ((1, 99, 100), 2204613.0), ((0, 95, 100), 2203500.0), ((1, 98, 100), 2203326.0), ((0, 94, 100), 2202200.0), ((1, 97, 100), 2202039.0), ((2, 100, 100), 2201800.0), ((0, 93, 100), 2200900.0), ((1, 96, 100), 2200752.0), ((2, 99, 100), 2200526.0), ((0, 92, 100), 2199600.0), ((1, 95, 100), 2199465.0), ((2, 98, 100), 2199252.0), ((0, 91, 100), 2198300.0), ((1, 94, 100), 2198178.0), ((2, 97, 100), 2197978.0), ((3, 100, 100), 2197700.0), ((0, 90, 100), 2197000.0), ((1, 93, 100), 2196891.0), ((2, 96, 100), 2196704.0), ((3, 99, 100), 2196439.0), ((0, 89, 100), 2195700.0), ((1, 92, 100), 2195604.0), ((2, 95, 100), 2195430.0), ((3, 98, 100), 2195178.0), ((0, 88, 100), 2194400.0), ((1, 91, 100), 2194317.0), ((2, 94, 100), 2194156.0), ((3, 97, 100), 2193917.0), ((4, 100, 100), 2193600.0), ((0, 87, 100), 2193100.0), ((1, 90, 100), 2193030.0), ((2, 93, 100), 2192882.0), ((3, 96, 100), 2192656.0), ((4, 99, 100), 2192352.0), ((0, 86, 100), 2191800.0), ((1, 89, 100), 2191743.0), ((2, 92, 100), 2191608.0), ((3, 95, 100), 2191395.0), ((4, 98, 100), 2191104.0), ((0, 85, 100), 2190500.0), ((1, 88, 100), 2190456.0), ((2, 91, 100), 2190334.0), ((3, 94, 100), 2190134.0), ((4, 97, 100), 2189856.0), ((5, 100, 100), 2189500.0), ((0, 84, 100), 2189200.0), ((1, 87, 100), 2189169.0), ((2, 90, 100), 2189060.0), ((3, 93, 100), 2188873.0), ((4, 96, 100), 2188608.0), ((5, 99, 100), 2188265.0), ((0, 83, 100), 2187900.0), ((1, 86, 100), 2187882.0), ((2, 89, 100), 2187786.0), ((3, 92, 100), 2187612.0), ((4, 95, 100), 2187360.0), ((5, 98, 100), 2187030.0), ((0, 82, 100), 2186600.0), ((1, 85, 100), 2186595.0), ((2, 88, 100), 2186512.0), ((3, 91, 100), 2186351.0), ((4, 94, 100), 2186112.0), ((5, 97, 100), 2185795.0), ((6, 100, 100), 2185400.0), ((1, 84, 100), 2185308.0), ((0, 81, 100), 2185300.0), ((2, 87, 100), 2185238.0), ((3, 90, 100), 2185090.0), ((4, 93, 100), 2184864.0), ((5, 96, 100), 2184560.0), ((6, 99, 100), 2184178.0), ((1, 83, 100), 2184021.0), ((0, 80, 100), 2184000.0), ((2, 86, 100), 2183964.0), ((3, 89, 100), 2183829.0), ((4, 92, 100), 2183616.0), ((5, 95, 100), 2183325.0), ((6, 98, 100), 2182956.0), ((1, 82, 100), 2182734.0), ((0, 79, 100), 2182700.0), ((2, 85, 100), 2182690.0), ((3, 88, 100), 2182568.0), ((4, 91, 100), 2182368.0), ((5, 94, 100), 2182090.0), ((6, 97, 100), 2181734.0), ((1, 81, 100), 2181447.0), ((2, 84, 100), 2181416.0), ((0, 78, 100), 2181400.0), ((3, 87, 100), 2181307.0), ((7, 100, 100), 2181300.0), ((4, 90, 100), 2181120.0), ((5, 93, 100), 2180855.0), ((6, 96, 100), 2180512.0), ((1, 80, 100), 2180160.0), ((2, 83, 100), 2180142.0), ((0, 77, 100), 2180100.0), ((7, 99, 100), 2180091.0), ((3, 86, 100), 2180046.0), ((4, 89, 100), 2179872.0), ((5, 92, 100), 2179620.0), ((6, 95, 100), 2179290.0), ((7, 98, 100), 2178882.0), ((1, 79, 100), 2178873.0), ((2, 82, 100), 2178868.0), ((0, 76, 100), 2178800.0), ((3, 85, 100), 2178785.0), ((4, 88, 100), 2178624.0), ((5, 91, 100), 2178385.0), ((6, 94, 100), 2178068.0), ((7, 97, 100), 2177673.0), ((2, 81, 100), 2177594.0), ((1, 78, 100), 2177586.0), ((3, 84, 100), 2177524.0), ((0, 75, 100), 2177500.0), ((4, 87, 100), 2177376.0), ((8, 100, 100), 2177200.0), ((5, 90, 100), 2177150.0), ((6, 93, 100), 2176846.0), ((7, 96, 100), 2176464.0), ((2, 80, 100), 2176320.0), ((1, 77, 100), 2176299.0), ((3, 83, 100), 2176263.0), ((0, 74, 100), 2176200.0), ((4, 86, 100), 2176128.0), ((8, 99, 100), 2176004.0), ((5, 89, 100), 2175915.0), ((6, 92, 100), 2175624.0), ((7, 95, 100), 2175255.0), ((2, 79, 100), 2175046.0), ((1, 76, 100), 2175012.0), ((3, 82, 100), 2175002.0), ((0, 73, 100), 2174900.0), ((4, 85, 100), 2174880.0), ((8, 98, 100), 2174808.0), ((5, 88, 100), 2174680.0), ((6, 91, 100), 2174402.0), ((7, 94, 100), 2174046.0), ((2, 78, 100), 2173772.0), ((3, 81, 100), 2173741.0), ((1, 75, 100), 2173725.0), ((4, 84, 100), 2173632.0), ((8, 97, 100), 217361 ...
